# %% [markdown]
# # 1. Exploring the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_data():
    
    #Importing CSV
    file_path = '/Users/mairagutierrez/Documents/Ironhack/PROJECTS/project--I/data/attacks.csv'
    
    # Try reading the file with a different encoding
    data = pd.read_csv(file_path, encoding='latin1')

    return data
    
data = get_data()
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# ## 1.1 Viewing Data

# %%
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
data.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
data.sample(5)
# Out:
#       Case Number         Date    Year        Type    Country        Area  \
# 24014         NaN          NaN     NaN         NaN        NaN         NaN
# 25169         NaN          NaN     NaN         NaN        NaN         NaN
# 19407         NaN          NaN     NaN         NaN        NaN         NaN
# 9393          NaN          NaN     NaN         NaN        NaN         NaN
# 4515   1949.04.17  17-Apr-1949  1949.0  Unprovoked  AUSTRALIA  Queensland
#
#                                 Location                     Activity  \
# 24014                                NaN                          NaN
# 25169                                NaN                          NaN
# 19407                                NaN                          NaN
# 9393                                 NaN                          NaN
# 4515   Ellis Beach, 20 miles from Cairns  Bathing in water 0.9 m deep
#
#                          Name Sex   ...             Species   \
# ...

# %%
#Getting columns information
data_columns = data.columns
data_columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time',
#        'Species', 'InvestigatororSource', 'pdf', 'hrefformula', 'href',
#        'CaseNumber.1', 'CaseNumber.2', 'originalorder', 'Unnamed:22',
#        'Unnamed:23'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ','')
data_columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time',
#        'Species', 'InvestigatororSource', 'pdf', 'hrefformula', 'href',
#        'CaseNumber.1', 'CaseNumber.2', 'originalorder', 'Unnamed:22',
#        'Unnamed:23'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Descriptive Statistics

# %%
#Initial Data Shape
data.shape
# Out:
# (25723, 24)

# %%
#Data describe for Numerical Columns
data.describe()
# Out:
#               Year  originalorder
# count  6300.000000    6309.000000
# mean   1927.272381    3155.999683
# std     281.116308    1821.396206
# min       0.000000       2.000000
# 25%    1942.000000    1579.000000
# 50%    1977.000000    3156.000000
# 75%    2005.000000    4733.000000
# max    2018.000000    6310.000000

# %%
#Data describe for CategoricalColumns
data.describe(include = 'object')
# Out:
#        CaseNumber  Date        Type Country     Area  \
# count        8702  6302        6298    6252     5847
# unique       6287  5433           8     212      825
# top             0  1957  Unprovoked     USA  Florida
# freq         2400    11        4595    2229     1037
#
#                                 Location Activity  Name   Sex   Age  ...  \
# count                               5762     5758  6092  5737  3471  ...
# unique                              4108     1532  5230     6   157  ...
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17  ...
# freq                                 163      971   550  5094   154  ...
#
#              Time      Species InvestigatororSource  \
# count        2948         3464                 6285
# unique        366         1549                 4969
# top     Afternoon  White shark       C. Moore, GSAF
# freq          187          163                  105
#
#                                   pdf  \
# ...

# %% [markdown]
# ## 1.3 Data Types and Missing Values

# %%
#Type of data in the Dataset
data.dtypes
# Out:
# CaseNumber               object
# Date                     object
# Year                    float64
# Type                     object
# Country                  object
# Area                     object
# Location                 object
# Activity                 object
# Name                     object
# Sex                      object
# Age                      object
# Injury                   object
# Fatal(Y/N)               object
# Time                     object
# Species                  object
# InvestigatororSource     object
# pdf                      object
# hrefformula              object
# href                     object
# CaseNumber.1             object
# CaseNumber.2             object
# originalorder           float64
# Unnamed:22               object
# Unnamed:23               object
# dtype: object

# %%
#Number of missing values in each column
missing_values = data.isnull().sum()

#Percent of the values of each columns over the total values
missing_percent = (missing_values /len(data))*100

#Presenting missing data as a dataframe
missing_data = pd.DataFrame({"Total values missing": missing_values, "Percentage": missing_percent})

#Sorting missing data from more missing values to less (descending)
missing_data = missing_data[missing_data["Total values missing"] > 0].sort_values(by = "Total values missing", ascending = False)

missing_data
# Out:
#                       Total values missing  Percentage
# Unnamed:22                           25722   99.996112
# Unnamed:23                           25721   99.992225
# Time                                 22775   88.539439
# Species                              22259   86.533453
# Age                                  22252   86.506240
# Sex                                  19986   77.697003
# Activity                             19965   77.615364
# Location                             19961   77.599813
# Fatal(Y/N)                           19960   77.595926
# Area                                 19876   77.269370
# Name                                 19631   76.316915
# Country                              19471   75.694903
# Injury                               19449   75.609377
# InvestigatororSource                 19438   75.566614
# Type                                 19425   75.516075
# Year                                 19423   75.508300
# ...

# %%
#YEAR

nat_count_year = data['Year'].isna().sum()
num_uniq_year = data['Year'].nunique()
print(nat_count_year, num_uniq_year)
# Out:
# 19423 249

# %% [markdown]
# ## 1.4 Univariate analysis

# %%
sns. set_style("whitegrid")

#Univariatr analysis of 'Type'column

plt.figure(figsize=(10, 6))
sns.countplot(data=data, y='Type', order = data['Type'].value_counts().index)
plt.title('Distribution of Shark Attack Types')
plt.xlabel('Count')
plt.ylabel('Type')
plt.show()
